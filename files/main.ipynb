# %% [markdown]
# ## Evaluation 1

# %% [markdown]
# ### Randomforest

# %%
from classifiers import *


feature_cols = ['Zipcode']
bool_columns = ['Street']

predictor = AccidentSeverityPredictor(feature_cols, bool_columns, window_duration, slide_duration)

df_pa = predictor.load_and_preprocess_data("data/US_Accidents_March23.csv")

[predictions, accuracy] = predictor.randomforest(df_pa, numTrees=1)
# Out:
# [Stage 42:===========================================>            (18 + 5) / 23]
# Test Accuracy = 0.626271

# %%
from classifiers import *


feature_cols = ['Zipcode']
bool_columns = ['Street']

predictor = AccidentSeverityPredictor(feature_cols, bool_columns, window_duration, slide_duration)

df_pa = predictor.load_and_preprocess_data("data/US_Accidents_March23.csv")

[predictions, accuracy] = predictor.randomforest(df_pa, numTrees=5)
# Out:
# [Stage 67:=========================================>              (17 + 6) / 23]
# Test Accuracy = 0.679007

# %%
from classifiers import *


feature_cols = ['Zipcode']
bool_columns = ['Street']

predictor = AccidentSeverityPredictor(feature_cols, bool_columns, window_duration, slide_duration)

df_pa = predictor.load_and_preprocess_data("data/US_Accidents_March23.csv")

[predictions, accuracy] = predictor.randomforest(df_pa, numTrees=20)
# Out:
# [Stage 92:==================================>                     (14 + 9) / 23]
# Test Accuracy = 0.679363

# %%
from classifiers import *


feature_cols = ['Zipcode']
bool_columns = ['Street']

predictor = AccidentSeverityPredictor(feature_cols, bool_columns, window_duration, slide_duration)

df_pa = predictor.load_and_preprocess_data("data/US_Accidents_March23.csv")

[predictions, accuracy] = predictor.randomforest(df_pa, numTrees=50)
# Out:
# [Stage 117:===================================>                   (15 + 8) / 23]
# Test Accuracy = 0.703697

# %% [markdown]
# ### Naive Bayes

# %%
from classifiers import *


feature_cols = ['Zipcode']
bool_columns = ['Street']

predictor = AccidentSeverityPredictor(feature_cols, bool_columns)

df_pa = predictor.load_and_preprocess_data("data/US_Accidents_March23.csv")

[predictions, accuracy] = predictor.naivebayes(df_pa, smoothing=0)
# Out:
# 23/12/19 18:50:21 WARN Utils: Your hostname, diego-swamslab resolves to a loopback address: 127.0.1.1; using 128.180.200.192 instead (on interface wlp0s20f3)
# 23/12/19 18:50:21 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/12/19 18:50:21 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 23/12/19 18:50:26 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# [Stage 4:=======================================>                 (16 + 7) / 23]
# ZeroR Model Test Accuracy = 0.918847

# %%
from classifiers import *


feature_cols = ['Zipcode']
bool_columns = ['Street']

predictor = AccidentSeverityPredictor(feature_cols, bool_columns)

df_pa = predictor.load_and_preprocess_data("data/US_Accidents_March23.csv")

[predictions, accuracy] = predictor.naivebayes(df_pa, smoothing=0.5)
# Out:
# [Stage 10:=========================================>              (17 + 6) / 23]
# ZeroR Model Test Accuracy = 0.918847

# %%
from classifiers import *


feature_cols = ['Zipcode']
bool_columns = ['Street']

predictor = AccidentSeverityPredictor(feature_cols, bool_columns)

df_pa = predictor.load_and_preprocess_data("data/US_Accidents_March23.csv")

[predictions, accuracy] = predictor.naivebayes(df_pa, smoothing=1)
# Out:
# [Stage 16:================================================>       (20 + 3) / 23]
# ZeroR Model Test Accuracy = 0.918847

# %% [markdown]
# ### LogisticRegression

# %%
from classifiers import *


feature_cols = ['Zipcode']
bool_columns = ['Street']

predictor = AccidentSeverityPredictor(feature_cols, bool_columns)

df_pa = predictor.load_and_preprocess_data("data/US_Accidents_March23.csv")

[predictions, accuracy] = predictor.logisticregression(df_pa, maxIter=1)

# %%
from classifiers import *


feature_cols = ['Zipcode']
bool_columns = ['Street']

predictor = AccidentSeverityPredictor(feature_cols, bool_columns)

df_pa = predictor.load_and_preprocess_data("data/US_Accidents_March23.csv")

[predictions, accuracy] = predictor.logisticregression(df_pa, maxIter=100)
# Out:
# [Stage 118:==================================================>    (21 + 2) / 23]
# Test Accuracy = 0.909403

# %%
from classifiers import *


feature_cols = ['Zipcode']
bool_columns = ['Street']

predictor = AccidentSeverityPredictor(feature_cols, bool_columns)

df_pa = predictor.load_and_preprocess_data("data/US_Accidents_March23.csv")

[predictions, accuracy] = predictor.logisticregression(df_pa, maxIter=200)
# Out:
# 23/12/19 19:10:25 WARN Utils: Your hostname, diego-swamslab resolves to a loopback address: 127.0.1.1; using 128.180.200.192 instead (on interface wlp0s20f3)
# 23/12/19 19:10:25 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/12/19 19:10:25 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %% [markdown]
# # Experimet 2

# %% [markdown]
# ### Random Forest

# %%
from classifiers import *


feature_cols = ['Grid','Zipcode']
bool_columns = ['Street', "Crossing", "Junction", "Stop", "Traffic_Signal"]
window_duration = "7 day"
slide_duration = "5 day"

predictor = AccidentSeverityPredictor(feature_cols, bool_columns, window_duration, slide_duration)

df_pa = predictor.load_and_preprocess_data("data/US_Accidents_March23.csv")
df_pa = df_pa.withColumn("Grid", find_grid_udf("Start_Lat", "Start_Lng"))

[predictions, accuracy] = predictor.randomforest(df_pa, numTrees=1)
# Out:
# [Stage 153:====================================================>  (22 + 1) / 23]
# Test Accuracy = 0.752187

# %%
from classifiers import *


feature_cols = ['Grid','Zipcode']
bool_columns = ['Street', "Crossing", "Junction", "Stop", "Traffic_Signal"]
window_duration = "7 day"
slide_duration = "5 day"

predictor = AccidentSeverityPredictor(feature_cols, bool_columns, window_duration, slide_duration)

df_pa = predictor.load_and_preprocess_data("data/US_Accidents_March23.csv")
df_pa = df_pa.withColumn("Grid", find_grid_udf("Start_Lat", "Start_Lng"))

[predictions, accuracy] = predictor.randomforest(df_pa, numTrees=1)
# Out:
# [Stage 153:====================================================>  (22 + 1) / 23]
# Test Accuracy = 0.752187

# %%
# from classifiers import *


# feature_cols = ['Grid','Zipcode', 'avg_temp', 'avg_visibility']
# bool_columns = ['Street', "Crossing", "Junction", "Stop", "Traffic_Signal"]
# window_duration = "7 day"
# slide_duration = "5 day"

# predictor = AccidentSeverityPredictor(feature_cols, bool_columns, window_duration, slide_duration)

# df_pa = predictor.load_and_preprocess_data("data/US_Accidents_March23.csv")

[predictions, accuracy] = predictor.randomforest(df_pa, numTrees=50)

# %% [markdown]
# ### Naive Bayes

# %%
from classifiers import *


feature_cols = ['Grid','Zipcode']
bool_columns = ['Street', "Crossing", "Junction", "Stop", "Traffic_Signal"]
window_duration = "7 day"
slide_duration = "5 day"

predictor = AccidentSeverityPredictor(feature_cols, bool_columns, window_duration, slide_duration)

df_pa = predictor.load_and_preprocess_data("data/US_Accidents_March23.csv")
df_pa = df_pa.withColumn("Grid", find_grid_udf("Start_Lat", "Start_Lng"))

[predictions, accuracy] = predictor.naivebayes(df_pa, smoothing=0)

# %%
from classifiers import *


feature_cols = ['Grid','Zipcode', 'avg_temp', 'avg_visibility']
bool_columns = ['Street', "Crossing", "Junction", "Stop", "Traffic_Signal"]
window_duration = "7 day"
slide_duration = "5 day"

predictor = AccidentSeverityPredictor(feature_cols, bool_columns, window_duration, slide_duration)

df_pa = predictor.load_and_preprocess_data("data/US_Accidents_March23.csv")
df_pa = predictor.create_windowed_dataframe(df_pa)

[predictions, accuracy] = predictor.randomforest(df_pa)
# Out:
# [Stage 191:==================================================>    (21 + 2) / 23]
# Test Accuracy = 0.787733

# %% [markdown]
# ### Experiment 3

# %%
from classifiers import *


feature_cols = ['Grid','Zipcode', 'avg_temp', 'avg_visibility']
bool_columns = ['Street', "Crossing", "Junction", "Stop", "Traffic_Signal"]
window_duration = "7 day"
slide_duration = "5 day"

predictor = AccidentSeverityPredictor(feature_cols, bool_columns, window_duration, slide_duration)

df_pa = predictor.load_and_preprocess_data("data/US_Accidents_March23.csv")
df_pa = predictor.create_windowed_dataframe(df_pa)

[predictions, accuracy] = predictor.naivebayes(df_pa, smoothing = 1)
# Out:
# [Stage 201:====================================================>  (22 + 1) / 23]
# ZeroR Model Test Accuracy = 0.925376

# %%
from classifiers import *


feature_cols = ['Grid','Zipcode', 'avg_temp', 'avg_visibility']
bool_columns = ['Street', "Crossing", "Junction", "Stop", "Traffic_Signal"]
window_duration = "7 day"
slide_duration = "5 day"

predictor = AccidentSeverityPredictor(feature_cols, bool_columns, window_duration, slide_duration)

df_pa = predictor.load_and_preprocess_data("data/US_Accidents_March23.csv")
df_pa = predictor.create_windowed_dataframe(df_pa)

[predictions, accuracy] = predictor.naivebayes(df_pa, smoothing = 0.5)
# Out:
# [Stage 214:==================================================>    (21 + 2) / 23]
# ZeroR Model Test Accuracy = 0.925376

# %%
from classifiers import *


feature_cols = ['Grid','Zipcode', 'avg_temp', 'avg_visibility']
bool_columns = ['Street', "Crossing", "Junction", "Stop", "Traffic_Signal"]
window_duration = "7 day"
slide_duration = "5 day"

predictor = AccidentSeverityPredictor(feature_cols, bool_columns, window_duration, slide_duration)

df_pa = predictor.load_and_preprocess_data("data/US_Accidents_March23.csv")
df_pa = predictor.create_windowed_dataframe(df_pa)

[predictions, accuracy] = predictor.naivebayes(df_pa, smoothing = 0)
# Out:
# [Stage 226:====================================================>  (22 + 1) / 23]
# ZeroR Model Test Accuracy = 0.925376

# %% [markdown]
# ### RandomForest

# %%
from classifiers import *


feature_cols = ['Grid', 'Zipcode', 'avg_temp', 'avg_visibility']
bool_columns = ['Street', "Crossing", "Junction", "Stop", "Traffic_Signal"]
window_duration = "7 day"
slide_duration = "5 day"

predictor = AccidentSeverityPredictor(feature_cols, bool_columns, window_duration, slide_duration)

df_pa = predictor.load_and_preprocess_data("data/US_Accidents_March23.csv")
df_pa = df_pa.withColumn("Grid", find_grid_udf("Start_Lat", "Start_Lng"))
df_pa = predictor.create_windowed_dataframe(df_pa)

[predictions, accuracy] = predictor.randomforest(df_pa)
# Out:
# 23/12/19 16:10:02 WARN Utils: Your hostname, diego-swamslab resolves to a loopback address: 127.0.1.1; using 128.180.200.192 instead (on interface wlp0s20f3)
# 23/12/19 16:10:02 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/12/19 16:10:03 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 23/12/19 16:10:08 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# /home/diego/.local/lib/python3.10/site-packages/pyspark/python/lib/pyspark.zip/pyspark/sql/pandas/serializers.py:224: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %% [markdown]
# ### Logistic Function

# %%
from classifiers import *


feature_cols = ['Grid', 'Zipcode', 'avg_temp', 'avg_visibility']
bool_columns = ['Street', "Crossing", "Junction", "Stop", "Traffic_Signal"]
window_duration = "7 day"
slide_duration = "5 day"

predictor = AccidentSeverityPredictor(feature_cols, bool_columns, window_duration, slide_duration)

df_pa = predictor.load_and_preprocess_data("data/US_Accidents_March23.csv")
df_pa = df_pa.withColumn("Grid", find_grid_udf("Start_Lat", "Start_Lng"))
df_pa = predictor.create_windowed_dataframe(df_pa)

[predictions, accuracy] = predictor.logisticregression(df_pa, maxIter=1)
# Out:
# [Stage 279:====================================================>  (22 + 1) / 23]
# Test Accuracy = 0.814844

# %%
from classifiers import *


feature_cols = ['Zipcode', 'avg_temp', 'avg_visibility']
bool_columns = ['Street', "Crossing", "Junction", "Stop", "Traffic_Signal"]
window_duration = "30 day"
slide_duration = "5 day"

predictor = AccidentSeverityPredictor(feature_cols, bool_columns, window_duration, slide_duration)

df_pa = predictor.load_and_preprocess_data("data/US_Accidents_March23.csv")
# df_pa = predictor.create_windowed_dataframe(df_pa)

# [predictions, accuracy] = predictor.randomforest(df_pa)

# predictor.sparkstop()

# %%
df_pa = df_pa.withColumn("Grid", find_grid_udf("Start_Lat", "Start_Lng"))

# %%
df_pa = predictor.create_windowed_dataframe(df_pa)

# %%
[predictions, accuracy] = predictor.randomforest(df_pa)
# Out:
# /home/diego/.local/lib/python3.10/site-packages/pyspark/python/lib/pyspark.zip/pyspark/sql/pandas/serializers.py:224: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# /home/diego/.local/lib/python3.10/site-packages/pyspark/python/lib/pyspark.zip/pyspark/sql/pandas/serializers.py:224: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# /home/diego/.local/lib/python3.10/site-packages/pyspark/python/lib/pyspark.zip/pyspark/sql/pandas/serializers.py:224: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %%
from utility import *

# %matplotlib inline

plotter = AccidentPlotter(df_pa, predictions)
plotter.plot_accidents()

# %%
from utility import *

# %matplotlib inline

plotter = AccidentPlotter(df_pa, predictions)
plotter.plot_accidents()
# Out:
# /home/diego/.local/lib/python3.10/site-packages/pyspark/python/lib/pyspark.zip/pyspark/sql/pandas/serializers.py:224: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# /home/diego/.local/lib/python3.10/site-packages/pyspark/python/lib/pyspark.zip/pyspark/sql/pandas/serializers.py:224: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead

# %%
plotter.plot_confusion_matrix()
